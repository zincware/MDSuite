# %%
import mdsuite as mds

# %%
NaCl_1074_15K = mds.Trajectory(analysis_name="NaCl_1074_15K_GK",
                        new_project=False,
                        temperature=1074.15,
                        filename="/beegfs/work/stovey/Masters_Simulations/NaCl/scaledSim/Thesis_Sims/1074K/VACF/NaCl_Velocities.xyz",
                        time_step=0.002,
                        time_unit=1e-12,
                        length_unit=1e-10,
                        storage_path="/data/stovey/New")
NaCl_1074_15K.species['Cl']['charge'] = [-1]
NaCl_1074_15K.species['Na']['charge'] = [+1]

# %%
NaCl_1074_15K.einstein_diffusion_coefficients(plot=True)
# Out:
# ...
# 100%|██████████| 500/500 [00:06<00:00, 80.83it/s]
# Einstein Self-Diffusion Coefficients:
#
# Na: 7.620232424537917e-09 m^2/s
#
# Cl: 5.7512474266753e-09 m^2/s

# %%
NaCl_1074_15K.green_kubo_diffusion_coefficients(plot=True, data_range=5000)
# Out:
# ...
# 100%|██████████| 100/100 [01:15<00:00,  1.32it/s]
# Self-Diffusion Coefficient for Na at 1074.15K: 7.924146484327962e-09 m^2/s
# Self-Diffusion Coefficient for Cl at 1074.15K: 5.854722206434094e-09 m^2/s

# %%
NaCl_1074_15K.einstein_helfand_conductivity(plot=True, data_range=2500)
# Out:
# 100%|██████████| 497501/497501 [00:23<00:00, 21574.20it/s]
# Einstein-Helfand Conductivity at 1074.15K: 3.3640243943152193 +- 0.005890200340128993 S/cm

# %%
NaCl_1074_15K.green_kubo_conductivity(plot=True, data_range=2500)
# Out:
# 100%|██████████| 497499/497499 [09:27<00:00, 877.08it/s]
# Green-Kubo Ionic Conductivity at 1074.15K: 3.4194647518818697 +- 0.004047079321439711 S/cm

# %%
NaCl_1074_15K.nernst_einstein_conductivity()
# Out:
# Nernst-Einstein Conductivity from Einstein Diffusion: 3.695416759913272 S/cm
# Nernst-Einstein Conductivity from Green-Kubo Diffusion: 3.808005012090447 S/cm
