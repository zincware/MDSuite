# %%
from __init__ import *

# %%
NaCl_1074K = Trajectory(analysis_name="1074K_VACF",
                      storage_path="/data/stovey",
                      new_project=False)
NaCl_1074K.sample_rate = 1

NaCl_1148K = Trajectory(analysis_name="1148K_VACF",
                      storage_path="/data/stovey",
                      new_project=False)
NaCl_1148K.sample_rate = 1


NaCl_1174K = Trajectory(analysis_name="1174K_VACF",
                      storage_path="/data/stovey",
                     new_project=False)
NaCl_1174K.sample_rate = 1


NaCl_1300K = Trajectory(analysis_name="1300K_VACF",
                      storage_path="/data/stovey",
                      new_project=False)
NaCl_1300K.sample_rate = 1


NaCl_1350K = Trajectory(analysis_name="1350K_VACF",
                      storage_path="/data/stovey",
                      new_project=False)
NaCl_1350K.sample_rate = 1


NaCl_1400K = Trajectory(analysis_name="1400_VACF",
                      storage_path="/data/stovey",
                      new_project=False)
NaCl_1400K.sample_rate = 1


NaCl_1450K = Trajectory(analysis_name="1450K_VACF",
                      storage_path="/data/stovey",
                      new_project=False)
NaCl_1450K.sample_rate = 1


class_array = [NaCl_1074K, NaCl_1148K, NaCl_1300K, NaCl_1350K, NaCl_1400K, NaCl_1450K]

# %%
sigma = []
temp = []
for obj in class_array:
    sigma.append(obj.Green_Kubo_Conductivity(1250, plot=True))
    temp.append(obj.temperature)
# Out:
# Green-Kubo Ionic Conductivity at 1074.0K: 3.4816663578970424 +- 0.003704699197294206 S/cm^2
# Green-Kubo Ionic Conductivity at 1148.0K: 3.8048262953686542 +- 0.003848856139848074 S/cm^2
# Green-Kubo Ionic Conductivity at 1300.0K: 4.006356081847142 +- 0.004204149581526357 S/cm^2
# Green-Kubo Ionic Conductivity at 1350.0K: 4.285005953345107 +- 0.004236808166903135 S/cm^2
# Green-Kubo Ionic Conductivity at 1400.0K: 4.471036433048775 +- 0.0044552845141874655 S/cm^2
# Green-Kubo Ionic Conductivity at 1450.0K: 4.388512158703186 +- 0.004445576304814346 S/cm^2

# %%
plt.scatter(temp, sigma)
plt.xlabel('Temperature (K)')
plt.ylabel('Ionic Conductivity')
plt.show()

# %%
NaCl_1174K.Green_Kubo_Conductivity(1250, plot=True)
# Out:
# Green-Kubo Ionic Conductivity at 1174.0K: 3.92348366570508 +- 0.00399384870270012 S/cm^2
# 392.348366570508

# %%
sigma
# Out:
# [348.16663578970423,
#  380.48262953686543,
#  400.63560818471416,
#  428.50059533451065,
#  447.1036433048775,
#  438.8512158703186,
#  3.9234,
#  392.34]

# %%
sigma = [348.16663578970423,
 380.48262953686543,
 400.63560818471416,
 428.50059533451065,
 447.1036433048775,
 438.8512158703186,
 392.34]

# %%
temp
# Out:
# [1074.0, 1148.0, 1300.0, 1350.0, 1400.0, 1450.0, 1174, 1174]

# %%
temp = [1074.0, 1148.0, 1300.0, 1350.0, 1400.0, 1450.0, 1174]

# %%
plt.scatter(temp, sigma)
plt.xlabel('Temperature (K)')
plt.ylabel('Ionic Conductivity')
plt.show()
